# %%
from SimPEG import *
from simpegem1d import EM1D, EM1DAnal, Kernels, RTEfun, DigFilter, BaseEM1D
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
TDsurvey = BaseEM1D.EM1DSurveyTD()
TDsurvey.rxLoc = np.array([0., 0., 100.+30.])
TDsurvey.txLoc = np.array([0., 0., 100.+80.])
TDsurvey.fieldtype = 'secondary'
TDsurvey.rxType = 'dBzdt'
TDsurvey.waveType = 'stepoff'
TDsurvey.txType = 'VMD'
TDsurvey.offset = 1e-5
# TDsurvey.a = 2.5
# TDsurvey.I = 1.
cs = 10.
nearthick = np.logspace(-1, 1, 3)
linthick = np.ones(10)*cs
deepthick = np.logspace(1, 2, 3)
hx = np.r_[nearthick, linthick, deepthick, deepthick[-1]]
mesh1D = Mesh.TensorMesh([hx], [0.])
depth = -mesh1D.gridN[:-1]
LocSigZ = -mesh1D.gridCC
nlay = depth.size
topo = np.r_[0., 0., 100.]
TDsurvey.depth = depth
TDsurvey.topo = topo
TDsurvey.LocSigZ = LocSigZ
TDsurvey.time = np.logspace(-4, -3, 64)
TDsurvey.setFrequency(TDsurvey.time)
TDsurvey.Setup1Dsystem()
sig_half = 1e-3
sig_blk = 1e-2
chi_half = 0.
Logmodel = BaseEM1D.BaseEM1DModel(mesh1D)
model = Model.ComboModel(mesh1D, [Logmodel])

# %%
sig  = np.ones(nlay)*sig_half
blk_ind = (-30>LocSigZ) & (-70<LocSigZ)
sig[blk_ind] = sig_blk
m_true = np.log(sig)

# %%
fig, ax = subplots(1,1, figsize=(5, 8))
ax.plot(sig, LocSigZ,  'b.-')
ax.grid(color='k', alpha=0.5, linestyle='dashed', linewidth=0.5)
ax.set_xscale('log')
ax.set_xlim(1e-4, 1e1)
# Out:
# (0.0001, 10.0)

# %%
WT0, WT1, YBASE = DigFilter.LoadWeights()
options = {'WT0': WT0, 'WT1': WT1, 'YBASE': YBASE}
prob = EM1D.EM1D(model, **options)
if prob.ispaired:
    prob.unpair()
if TDsurvey.ispaired:
    TDsurvey.unpair()
prob.pair(TDsurvey)
prob.CondType = 'Real'
prob.chi = np.zeros(TDsurvey.nlay)
d_true = TDsurvey.dpred(m_true)

# %%
fig, axes = subplots(1,1, figsize = (7,5))
axes.plot(TDsurvey.time, -d_true, '.-')
axes.set_xscale('log');
axes.set_yscale('log');

# %%
TDsurvey.HalfSwitch = True
TDsurvey.Setup1Dsystem()
m_test = np.log(np.r_[sig_half])
d_test = TDsurvey.dpred(m_test)

# %%
fig, axes = subplots(1,1, figsize = (7,5))
axes.plot(TDsurvey.time, -d_true, '.-')
axes.plot(TDsurvey.time, -d_test, 'r.-')
axes.set_xscale('log');
axes.set_yscale('log');

# %%
TDsurvey.dtrue = d_true
std = 0.05
noise = std*abs(TDsurvey.dtrue)*np.random.randn(*TDsurvey.dtrue.shape)
TDsurvey.dobs = TDsurvey.dtrue+noise
TDsurvey.std = TDsurvey.dobs*0 + std
a  = 100.
weight = (1-exp(-a*TDsurvey.time))*np.linalg.norm(TDsurvey.dobs)
# TDsurvey.Wd = 1/(abs(TDsurvey.dobs)*std)
TDsurvey.Wd = 1/(weight)
prob.jacSwitch = True

# %%
plt.loglog(TDsurvey.time, weight, 'b.-', lw = 2)

# %%
mesh1D = Mesh.TensorMesh([np.ones(1)])
Logmodel = BaseEM1D.BaseEM1DModel(mesh1D)
model = Model.ComboModel(mesh1D, [Logmodel])

# %%
opt = Optimization.InexactGaussNewton(maxIter = 5)
reg = Regularization.Tikhonov(model)
obj = ObjFunction.BaseObjFunction(TDsurvey, reg, beta=beta)
# Create an inversion object
inv = Inversion.BaseInversion(obj, opt)
m0 = np.log(np.ones(TDsurvey.nlay)*sig_half*5)
reg.alpha_s = 1.
reg.alpha_x = 0
C =  Utils.Counter()
prob.counter = C
opt.counter = C
opt.LSshorten = 0.5
opt.remember('xc')
beta = Parameters.BetaSchedule(coolingFactor = 8, coolingRate = 1, beta0_ratio = 1e0)
inv.objFunc.beta = beta
# Out:
# Warning: Parameter beta has switched to a new parent.

# %%
mopt = inv.run(m0)
# Out:
# Regularization has not set mref. SimPEG will set it to m0.
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
#    0  1.33e+04  1.73e+02  5.00e-01  6.82e+03    1.54e+04      0
#    1  1.66e+03  5.48e+02  1.57e-01  8.10e+02    1.57e+03      0
#    2  2.08e+02  3.37e+01  3.11e-01  9.84e+01    4.65e+02      0
#    3  2.60e+01  1.35e+01  3.47e-01  2.25e+01    1.12e+02      0   Skip BFGS
#    4  3.25e+00  1.26e+01  3.56e-01  1.37e+01    1.53e+01      0   Skip BFGS
#    5  4.06e-01  1.26e+01  3.57e-01  1.27e+01    2.00e+00      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.0270e+00 <= tolF*(1+|f0|) = 6.8259e+02
# 1 : |xc-x_last| = 1.6091e-03 <= tolX*(1+|x0|) = 6.2983e-01
# 0 : |proj(x-g)-x|    = 1.9965e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9965e+00 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =       5    <= iter          =      5
# ------------------------- DONE! -------------------------

# %%
opt.counter.summary()
xc = opt.recall('xc')
# Out:
# Counters:
#   InexactGaussNewton.doEndIteration       :        5
#   InexactGaussNewton.doStartIteration     :        6
#   InexactGaussNewton.scaleSearchDirection :        5
#
# Times:                                        mean      sum
#   EM1D.Jtvec_approx                       : 1.79e-02, 1.08e-01,    6x
#   EM1D.Jvec_approx                        : 1.81e-02, 1.09e-01,    6x
#   InexactGaussNewton.findSearchDirection  : 4.46e-02, 2.23e-01,    5x
#   InexactGaussNewton.minimize             : 1.14e+01, 1.14e+01,    1x
#   InexactGaussNewton.modifySearchDirection: 1.00e+00, 5.00e+00,    5x
#   InexactGaussNewton.projection           : 4.82e-05, 1.25e-03,   26x

# %%
print opt.maxIter
# Out:
# 5

# %%
dpredall = []
maxIter = 5
for i in range(maxIter):
    dpredtemp = TDsurvey.dpred(xc[i])
    dpredall.append(dpredtemp)

# %%
from JSAnimation import IPython_display
from matplotlib import animation

fig, ax = subplots(1,2, figsize=(14, 8))
ax[0].plot(sig, LocSigZ,  'b.-', lw=2)
ax[0].grid(color='k', alpha=0.5, linestyle='dashed', linewidth=0.5)
ax[1].grid(color='k', alpha=0.5, linestyle='dashed', linewidth=0.5)

ax[1].plot(TDsurvey.time, -(d_true), 'r.-', lw=2)
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[0].set_xlim(1e-5, 1e0)


frame1, = ax[0].plot([], [],  'r.-', lw=2)
frame2, = ax[1].plot([], [],  'b.-' , lw=2)

def animate(i_id):
    
    frame1.set_data(model.transform(xc[i_id])*np.ones(LocSigZ.size), LocSigZ)
    frame2.set_data(TDsurvey.time, -(dpredall[i_id]))
    
    ax[0].legend(('True', 'Pred'), loc=1, fontsize = 14)
    ax[1].legend(('True', 'Pred'), loc=1, fontsize = 14)
    
    ax[0].set_title('$\sigma$ model, Iter = ' + str(i_id+1), fontsize = 16)
    ax[1].set_title('Pred and Obs data, Iter = ' + str(i_id+1), fontsize = 16)
    return frame1, frame2

animation.FuncAnimation(fig, animate, frames=maxIter, interval=40, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgVBISKZBQMNHTFFWI">
#     <br>
#     <input id="_anim_sliderVBISKZBQMNHTFFWI" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animVBISKZBQMNHTFFWI.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animVBISKZBQMNHTFFWI.slower()">&#8211;</button>
#     <button onclick="animVBISKZBQMNHTFFWI.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVBISKZBQMNHTFFWI.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectVBISKZBQMNHTFFWI" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgVBISKZBQMNHTFFWI";
#     var slider_id = "_anim_sliderVBISKZBQMNHTFFWI";
#     var loop_select_id = "_anim_loop_selectVBISKZBQMNHTFFWI";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzs3Xl4FEX+x/HPhCsHgSTcEJZwI4IEwqHIEfhxRpF4oMKq\
# nKK4eKDrKrqSQRfRXV1UPBBBUJRbwZOAqCMqp2hEBAWFUQ5BkUMwBAL074/aScgxIQkzmev9ep55\
# Mt3p6a6udKrm21VdZbMsyxIAAAAAAPBrYb5OAAAAAAAAODcCeAAAAAAAAgABPAAAAAAAAYAAHgAA\
# AACAAEAADwAAAABAACCABwAAAAAgABDAAwAAAAAQAAjgAQAAAAAIAATwAAAAAAAEAAJ4AAAAAAAC\
# AAE8AAAAAAABgAAeAAAAAIAAQAAPAAAAAEAAIIAHAAAAACAAEMADAAAAABAACOABAAAAAAgABPAA\
# AAAAAAQAAngAAAAAAAIAATwAAAAAAAGAAB4AAAAAgABAAA8AAAAAQAAggAcAAAAAIAAQwAMAAAAA\
# EAAI4AEAAAAACAAE8AAAAAAABAACeAAAAAAAAgABPAAAAAAAAYAAHgAAAACAAEAADwAAAABAACCA\
# BwAAAAAgABDAAwAAAAAQAAjgAQAAAAAIAATwAAAAAAAEAAJ4AAAAAAACAAE8AAAAAAABgAAeAAAA\
# AIAAQAAPAAAAAEAAIIAHAAAAACAAEMADAAAAABAACOABAAAAAAgABPAAykRycrJ69OhR4s/Z7XaF\
# hZWuqJo9e7bCwsK0Y8cOSdLSpUs1ZcqUUu3L13bv3q3bb79dl1xyiSIjIxUWFqaff/7Z18kCUIZc\
# ZZrrVaVKFSUmJuq5557T6dOnvXpsp9OpsLAwvfLKK149TnENGzZMDRs2LNa2hw4d0vjx49W8eXNF\
# RESoWrVq6tevn1asWFFgW1edc+bMGU8n2a3zydunnnpKS5Ys8UKq8nI4HAoLC9NHH32Us2727Nma\
# NWuW14/tDa+88oquvvpqNWjQQGFhYRo+fLivkwQUGwE8gDJhs9lks9lK/VlPWLp0qf773/96ZF9l\
